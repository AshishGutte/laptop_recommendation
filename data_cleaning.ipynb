# %%
import pandas as pd
import re

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv("flipkart_laptop_final.csv")

# Show the first 5 rows to confirm
df.head()
# Out:
#                                         Product Name  \
# 0  Lenovo IdeaPad Slim 5 Intel Core i5 13th Gen 1...
# 1  MOTOROLA Motobook 60 Full Metal Intel Core 7 (...
# 2  Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...
# 3  ASUS Vivobook 15 Intel Core i3 13th Gen 1315U ...
# 4  SAMSUNG Galaxy Book4 Metal Intel Core i5 13th ...
#
#                                       Specifications     Rating  \
# 0  Intel Core i5 Processor (13th Gen)16 GB DDR5 R...  Not found
# 1  Intel Core 7 (Series 2) Processor16 GB DDR5 RA...        4.2
# 2  Intel Celeron Dual Core Processor8 GB DDR4 RAM...        3.8
# 3  Intel Core i3 Processor (13th Gen)8 GB DDR4 RA...        4.2
# 4  Intel Core i5 Processor (13th Gen)16 GB LPDDR4...        4.5
#
#                      Price                                        Product URL  \
# 0                  ₹97,290  https://www.flipkart.com/lenovo-ideapad-slim-5...
# 1  ₹70,990₹1,04,89032% off  https://www.flipkart.com/motorola-motobook-60-...
# 2    ₹15,990₹33,99952% off  https://www.flipkart.com/acer-aspire-3-intel-c...
# 3    ₹35,990₹57,99037% off  https://www.flipkart.com/asus-vivobook-15-inte...
# 4    ₹54,990₹82,78933% off  https://www.flipkart.com/samsung-galaxy-book4-...
#
#          Battery Life   Weight  \
# 0     Integrated 60Wh  1.39 Kg
# 1     Lithium-Polymer   1.4 Kg
# 2  MS Office Provided   1.0 kg
# 3              3 Cell  1.70 Kg
# 4  MS Office Provided  1.55 Kg
#
#                                             Webcam          Display Size
# 0  FHD 1080p + IR with Privacy Shutter, ToF Sensor    35.56 cm (14 inch)
# 1                              Finger Print Sensor    35.56 cm (14 Inch)
# 2              1280 x 720 Resolution/720p HD Video  29.46 cm (11.6 inch)
# 3              720p HD camera With privacy shutter  39.62 cm (15.6 Inch)
# 4                                 Yes, 1 Megapixel  39.62 cm (15.6 Inch)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product Name    696 non-null    object
#  1   Specifications  696 non-null    object
#  2   Rating          696 non-null    object
#  3   Price           696 non-null    object
#  4   Product URL     696 non-null    object
#  5   Battery Life    696 non-null    object
#  6   Weight          696 non-null    object
#  7   Webcam          695 non-null    object
#  8   Display Size    696 non-null    object
# dtypes: object(9)
# memory usage: 49.1+ KB

# %%
df.isnull().sum()
# Out:
# Product Name      0
# Specifications    0
# Rating            0
# Price             0
# Product URL       0
# Battery Life      0
# Weight            0
# Webcam            1
# Display Size      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Product Name      object
# Specifications    object
# Rating            object
# Price             object
# Product URL       object
# Battery Life      object
# Weight            object
# Webcam            object
# Display Size      object
# dtype: object

# %%
df.nunique()
# Out:
# Product Name      389
# Specifications    360
# Rating             22
# Price             386
# Product URL       696
# Battery Life       79
# Weight            112
# Webcam             97
# Display Size       27
# dtype: int64

# %%
df.columns
# Out:
# Index(['Product Name', 'Specifications', 'Rating', 'Price', 'Product URL',
#        'Battery Life', 'Weight', 'Webcam', 'Display Size'],
#       dtype='object')

# %%
# =========================
# Price Cleaning
# =========================
df['Price'] = (
    df['Price'].astype(str)
    .str.extract(r'₹([\d,]+)')[0]
    .str.replace(',', '', regex=True)
    .astype(float)
)
df = df.dropna(subset=['Price'])
df['Price'] = df['Price'].astype(int)

# %%
df
# Out:
#                                           Product Name  \
# 0    Lenovo IdeaPad Slim 5 Intel Core i5 13th Gen 1...
# 1    MOTOROLA Motobook 60 Full Metal Intel Core 7 (...
# 2    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...
# 3    ASUS Vivobook 15 Intel Core i3 13th Gen 1315U ...
# 4    SAMSUNG Galaxy Book4 Metal Intel Core i5 13th ...
# ..                                                 ...
# 691  MSI Thin 15 Intel Core i5 12th Gen 12450H - (1...
# 692  ASUS Zenbook 14 OLED (2025) with Office 2024 +...
# 693  ASUS Expertbook P5 full metal AI PC Intel Core...
# 694  ASUS Vivobook S14 (2025) with Office 2024 + M3...
# 695  Lenovo V 15 (2025) Intel Core i3 12th Gen 1215...
#
#                                         Specifications     Rating   Price  \
# 0    Intel Core i5 Processor (13th Gen)16 GB DDR5 R...  Not found   97290
# 1    Intel Core 7 (Series 2) Processor16 GB DDR5 RA...        4.2   70990
# 2    Intel Celeron Dual Core Processor8 GB DDR4 RAM...        3.8   15990
# 3    Intel Core i3 Processor (13th Gen)8 GB DDR4 RA...        4.2   35990
# 4    Intel Core i5 Processor (13th Gen)16 GB LPDDR4...        4.5   54990
# ..                                                 ...        ...     ...
# 691  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...        4.3   50990
# 692  Intel Core Ultra 7 Processor32 GB LPDDR5X RAMW...        3.3  127990
# 693  Intel Core Ultra 5 Processor16 GB LPDDR5X RAMW...        4.7   94990
# 694  Intel Core i7 Processor (13th Gen)16 GB DDR5 R...  Not found   75990
# 695  Intel Core i3 Processor (12th Gen)16 GB DDR4 R...  Not found   33990
#
#                                            Product URL  \
# 0    https://www.flipkart.com/lenovo-ideapad-slim-5...
# 1    https://www.flipkart.com/motorola-motobook-60-...
# 2    https://www.flipkart.com/acer-aspire-3-intel-c...
# 3    https://www.flipkart.com/asus-vivobook-15-inte...
# 4    https://www.flipkart.com/samsung-galaxy-book4-...
# ..                                                 ...
# 691  https://www.flipkart.com/msi-thin-15-intel-cor...
# 692  https://www.flipkart.com/asus-zenbook-14-oled-...
# 693  https://www.flipkart.com/asus-expertbook-p5-fu...
# 694  https://www.flipkart.com/asus-vivobook-s14-202...
# 695  https://www.flipkart.com/lenovo-v-15-2025-inte...
#
#                     Battery Life   Weight  \
# 0                Integrated 60Wh  1.39 Kg
# 1                Lithium-Polymer   1.4 Kg
# 2             MS Office Provided   1.0 kg
# 3                         3 Cell  1.70 Kg
# 4             MS Office Provided  1.55 Kg
# ..                           ...      ...
# 691                 Model Number  1.86 Kg
# 692             Warranty Summary  1.28 Kg
# 693  63WHrs, 3S1P, 3-cell Li-ion  1.27 Kg
# 694                       4-cell  1.39 Kg
# 695             Warranty Summary   1.5 kg
#
#                                                 Webcam          Display Size
# 0      FHD 1080p + IR with Privacy Shutter, ToF Sensor    35.56 cm (14 inch)
# 1                                  Finger Print Sensor    35.56 cm (14 Inch)
# 2                  1280 x 720 Resolution/720p HD Video  29.46 cm (11.6 inch)
# 3                  720p HD camera With privacy shutter  39.62 cm (15.6 Inch)
# 4                                     Yes, 1 Megapixel  39.62 cm (15.6 Inch)
# ..                                                 ...                   ...
# 691                               HD type (30fps@720p)  39.62 cm (15.6 Inch)
# 692  FHD camera with IR function to support Windows...    35.56 cm (14 Inch)
# 693  1080p FHD camera with IR function to support W...    35.56 cm (14 Inch)
# 694  FHD camera with IR function to support Windows...    35.56 cm (14 inch)
# 695                                     720p HD camera  39.62 cm (15.6 inch)
#
# [696 rows x 9 columns]

# %%
df['Price'].describe()
# Out:
# count       696.000000
# mean      56803.386494
# std       32310.664849
# min        9999.000000
# 25%       35890.000000
# 50%       49990.000000
# 75%       69990.000000
# max      449990.000000
# Name: Price, dtype: float64

# %%
# =========================
# Remove 'Not found'  prices
# =========================
df = df[~(df['Price'] == 'Not found')]

# %%
df
# Out:
#                                           Product Name  \
# 0    Lenovo IdeaPad Slim 5 Intel Core i5 13th Gen 1...
# 1    MOTOROLA Motobook 60 Full Metal Intel Core 7 (...
# 2    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...
# 3    ASUS Vivobook 15 Intel Core i3 13th Gen 1315U ...
# 4    SAMSUNG Galaxy Book4 Metal Intel Core i5 13th ...
# ..                                                 ...
# 691  MSI Thin 15 Intel Core i5 12th Gen 12450H - (1...
# 692  ASUS Zenbook 14 OLED (2025) with Office 2024 +...
# 693  ASUS Expertbook P5 full metal AI PC Intel Core...
# 694  ASUS Vivobook S14 (2025) with Office 2024 + M3...
# 695  Lenovo V 15 (2025) Intel Core i3 12th Gen 1215...
#
#                                         Specifications     Rating   Price  \
# 0    Intel Core i5 Processor (13th Gen)16 GB DDR5 R...  Not found   97290
# 1    Intel Core 7 (Series 2) Processor16 GB DDR5 RA...        4.2   70990
# 2    Intel Celeron Dual Core Processor8 GB DDR4 RAM...        3.8   15990
# 3    Intel Core i3 Processor (13th Gen)8 GB DDR4 RA...        4.2   35990
# 4    Intel Core i5 Processor (13th Gen)16 GB LPDDR4...        4.5   54990
# ..                                                 ...        ...     ...
# 691  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...        4.3   50990
# 692  Intel Core Ultra 7 Processor32 GB LPDDR5X RAMW...        3.3  127990
# 693  Intel Core Ultra 5 Processor16 GB LPDDR5X RAMW...        4.7   94990
# 694  Intel Core i7 Processor (13th Gen)16 GB DDR5 R...  Not found   75990
# 695  Intel Core i3 Processor (12th Gen)16 GB DDR4 R...  Not found   33990
#
#                                            Product URL  \
# 0    https://www.flipkart.com/lenovo-ideapad-slim-5...
# 1    https://www.flipkart.com/motorola-motobook-60-...
# 2    https://www.flipkart.com/acer-aspire-3-intel-c...
# 3    https://www.flipkart.com/asus-vivobook-15-inte...
# 4    https://www.flipkart.com/samsung-galaxy-book4-...
# ..                                                 ...
# 691  https://www.flipkart.com/msi-thin-15-intel-cor...
# 692  https://www.flipkart.com/asus-zenbook-14-oled-...
# 693  https://www.flipkart.com/asus-expertbook-p5-fu...
# 694  https://www.flipkart.com/asus-vivobook-s14-202...
# 695  https://www.flipkart.com/lenovo-v-15-2025-inte...
#
#                     Battery Life   Weight  \
# 0                Integrated 60Wh  1.39 Kg
# 1                Lithium-Polymer   1.4 Kg
# 2             MS Office Provided   1.0 kg
# 3                         3 Cell  1.70 Kg
# 4             MS Office Provided  1.55 Kg
# ..                           ...      ...
# 691                 Model Number  1.86 Kg
# 692             Warranty Summary  1.28 Kg
# 693  63WHrs, 3S1P, 3-cell Li-ion  1.27 Kg
# 694                       4-cell  1.39 Kg
# 695             Warranty Summary   1.5 kg
#
#                                                 Webcam          Display Size
# 0      FHD 1080p + IR with Privacy Shutter, ToF Sensor    35.56 cm (14 inch)
# 1                                  Finger Print Sensor    35.56 cm (14 Inch)
# 2                  1280 x 720 Resolution/720p HD Video  29.46 cm (11.6 inch)
# 3                  720p HD camera With privacy shutter  39.62 cm (15.6 Inch)
# 4                                     Yes, 1 Megapixel  39.62 cm (15.6 Inch)
# ..                                                 ...                   ...
# 691                               HD type (30fps@720p)  39.62 cm (15.6 Inch)
# 692  FHD camera with IR function to support Windows...    35.56 cm (14 Inch)
# 693  1080p FHD camera with IR function to support W...    35.56 cm (14 Inch)
# 694  FHD camera with IR function to support Windows...    35.56 cm (14 inch)
# 695                                     720p HD camera  39.62 cm (15.6 inch)
#
# [696 rows x 9 columns]

# %%
def extract_laptop_name(text):
    return re.split(r'Intel|AMD|\(|-', text)[0].strip()

df['Clean Name'] = df['Product Name'].apply(extract_laptop_name)
df['Product Name'] = df['Clean Name']
df.drop(columns=['Clean Name'], inplace=True)

# %%
df
# Out:
#                             Product Name  \
# 0                  Lenovo IdeaPad Slim 5
# 1        MOTOROLA Motobook 60 Full Metal
# 2                          Acer Aspire 3
# 3                       ASUS Vivobook 15
# 4             SAMSUNG Galaxy Book4 Metal
# ..                                   ...
# 691                          MSI Thin 15
# 692                 ASUS Zenbook 14 OLED
# 693  ASUS Expertbook P5 full metal AI PC
# 694                    ASUS Vivobook S14
# 695                          Lenovo V 15
#
#                                         Specifications     Rating   Price  \
# 0    Intel Core i5 Processor (13th Gen)16 GB DDR5 R...  Not found   97290
# 1    Intel Core 7 (Series 2) Processor16 GB DDR5 RA...        4.2   70990
# 2    Intel Celeron Dual Core Processor8 GB DDR4 RAM...        3.8   15990
# 3    Intel Core i3 Processor (13th Gen)8 GB DDR4 RA...        4.2   35990
# 4    Intel Core i5 Processor (13th Gen)16 GB LPDDR4...        4.5   54990
# ..                                                 ...        ...     ...
# 691  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...        4.3   50990
# 692  Intel Core Ultra 7 Processor32 GB LPDDR5X RAMW...        3.3  127990
# 693  Intel Core Ultra 5 Processor16 GB LPDDR5X RAMW...        4.7   94990
# 694  Intel Core i7 Processor (13th Gen)16 GB DDR5 R...  Not found   75990
# 695  Intel Core i3 Processor (12th Gen)16 GB DDR4 R...  Not found   33990
#
#                                            Product URL  \
# 0    https://www.flipkart.com/lenovo-ideapad-slim-5...
# 1    https://www.flipkart.com/motorola-motobook-60-...
# 2    https://www.flipkart.com/acer-aspire-3-intel-c...
# 3    https://www.flipkart.com/asus-vivobook-15-inte...
# 4    https://www.flipkart.com/samsung-galaxy-book4-...
# ..                                                 ...
# 691  https://www.flipkart.com/msi-thin-15-intel-cor...
# 692  https://www.flipkart.com/asus-zenbook-14-oled-...
# 693  https://www.flipkart.com/asus-expertbook-p5-fu...
# 694  https://www.flipkart.com/asus-vivobook-s14-202...
# 695  https://www.flipkart.com/lenovo-v-15-2025-inte...
#
#                     Battery Life   Weight  \
# 0                Integrated 60Wh  1.39 Kg
# 1                Lithium-Polymer   1.4 Kg
# 2             MS Office Provided   1.0 kg
# 3                         3 Cell  1.70 Kg
# 4             MS Office Provided  1.55 Kg
# ..                           ...      ...
# 691                 Model Number  1.86 Kg
# 692             Warranty Summary  1.28 Kg
# 693  63WHrs, 3S1P, 3-cell Li-ion  1.27 Kg
# 694                       4-cell  1.39 Kg
# 695             Warranty Summary   1.5 kg
#
#                                                 Webcam          Display Size
# 0      FHD 1080p + IR with Privacy Shutter, ToF Sensor    35.56 cm (14 inch)
# 1                                  Finger Print Sensor    35.56 cm (14 Inch)
# 2                  1280 x 720 Resolution/720p HD Video  29.46 cm (11.6 inch)
# 3                  720p HD camera With privacy shutter  39.62 cm (15.6 Inch)
# 4                                     Yes, 1 Megapixel  39.62 cm (15.6 Inch)
# ..                                                 ...                   ...
# 691                               HD type (30fps@720p)  39.62 cm (15.6 Inch)
# 692  FHD camera with IR function to support Windows...    35.56 cm (14 Inch)
# 693  1080p FHD camera with IR function to support W...    35.56 cm (14 Inch)
# 694  FHD camera with IR function to support Windows...    35.56 cm (14 inch)
# 695                                     720p HD camera  39.62 cm (15.6 inch)
#
# [696 rows x 9 columns]

# %%
df['Brand'] = df['Product Name'].apply(lambda x: x.split()[0])

# %%
df["Specifications"] = df["Specifications"].astype(str).apply(
    lambda x: re.sub(r"(?<=[a-zA-Z])(?=\d)", " ", x)
)

# %%
def extract_feature(pattern, text):
    match = re.search(pattern, text)
    return match.group(0).strip() if match else "Not found"

df["Processor"] = df["Specifications"].apply(lambda x: extract_feature(r"(Intel|AMD|Celeron)[^,\n]*Processor\s*\([^)]*\)?", x))
df["RAM"] = df["Specifications"].apply(lambda x: extract_feature(r"\d+\s*GB", x))
df["DDR"] = df["Specifications"].apply(lambda x: extract_feature(r"(LP)?DDR\d?", x))
df["OS"] = df["Specifications"].apply(lambda x: extract_feature(r"Windows\s+11\s*(Home)?", x))
df["Storage"] = df["Specifications"].apply(lambda x: extract_feature(r"\d+\s*(GB|TB)\s*SSD", x))
df["Display"] = df["Specifications"].apply(lambda x: extract_feature(r"\d{2}\.\d{2}\s*cm\s*\([^)]+\)", x))
df["Warranty"] = df["Specifications"].apply(lambda x: extract_feature(r"\d+\s*Year\s+(Onsite|Carry-in)?\s*Warranty", x))

# %%
def format_product(row):
    return (
        f"Product: {row['Product Name']}, Brand: {row['Brand']}, Rating: {row['Rating']}, Price: ₹{row['Price']}, "
        f"Processor: {row['Processor']}, RAM: {row['RAM']} GB, DDR: {row['DDR']}, OS: {row['OS']}, "
        f"Storage: {row['Storage']}, "
        f"Weight: {row['Weight']} kg, "
        f"Warranty: {row['Warranty']}"
    )
df["text"] = df.apply(format_product, axis=1)

# %%
df
# Out:
#                             Product Name  \
# 0                  Lenovo IdeaPad Slim 5
# 1        MOTOROLA Motobook 60 Full Metal
# 2                          Acer Aspire 3
# 3                       ASUS Vivobook 15
# 4             SAMSUNG Galaxy Book4 Metal
# ..                                   ...
# 691                          MSI Thin 15
# 692                 ASUS Zenbook 14 OLED
# 693  ASUS Expertbook P5 full metal AI PC
# 694                    ASUS Vivobook S14
# 695                          Lenovo V 15
#
#                                         Specifications     Rating   Price  \
# 0    Intel Core i 5 Processor (13th Gen)16 GB DDR 5...  Not found   97290
# 1    Intel Core 7 (Series 2) Processor 16 GB DDR 5 ...        4.2   70990
# 2    Intel Celeron Dual Core Processor 8 GB DDR 4 R...        3.8   15990
# 3    Intel Core i 3 Processor (13th Gen)8 GB DDR 4 ...        4.2   35990
# 4    Intel Core i 5 Processor (13th Gen)16 GB LPDDR...        4.5   54990
# ..                                                 ...        ...     ...
# 691  Intel Core i 5 Processor (12th Gen)16 GB DDR 4...        4.3   50990
# 692  Intel Core Ultra 7 Processor 32 GB LPDDR 5X RA...        3.3  127990
# 693  Intel Core Ultra 5 Processor 16 GB LPDDR 5X RA...        4.7   94990
# 694  Intel Core i 7 Processor (13th Gen)16 GB DDR 5...  Not found   75990
# 695  Intel Core i 3 Processor (12th Gen)16 GB DDR 4...  Not found   33990
#
#                                            Product URL  \
# 0    https://www.flipkart.com/lenovo-ideapad-slim-5...
# 1    https://www.flipkart.com/motorola-motobook-60-...
# 2    https://www.flipkart.com/acer-aspire-3-intel-c...
# 3    https://www.flipkart.com/asus-vivobook-15-inte...
# 4    https://www.flipkart.com/samsung-galaxy-book4-...
# ..                                                 ...
# 691  https://www.flipkart.com/msi-thin-15-intel-cor...
# 692  https://www.flipkart.com/asus-zenbook-14-oled-...
# 693  https://www.flipkart.com/asus-expertbook-p5-fu...
# 694  https://www.flipkart.com/asus-vivobook-s14-202...
# 695  https://www.flipkart.com/lenovo-v-15-2025-inte...
#
#                     Battery Life   Weight  \
# 0                Integrated 60Wh  1.39 Kg
# 1                Lithium-Polymer   1.4 Kg
# 2             MS Office Provided   1.0 kg
# 3                         3 Cell  1.70 Kg
# 4             MS Office Provided  1.55 Kg
# ..                           ...      ...
# 691                 Model Number  1.86 Kg
# 692             Warranty Summary  1.28 Kg
# 693  63WHrs, 3S1P, 3-cell Li-ion  1.27 Kg
# 694                       4-cell  1.39 Kg
# 695             Warranty Summary   1.5 kg
#
#                                                 Webcam          Display Size  \
# 0      FHD 1080p + IR with Privacy Shutter, ToF Sensor    35.56 cm (14 inch)
# 1                                  Finger Print Sensor    35.56 cm (14 Inch)
# 2                  1280 x 720 Resolution/720p HD Video  29.46 cm (11.6 inch)
# 3                  720p HD camera With privacy shutter  39.62 cm (15.6 Inch)
# 4                                     Yes, 1 Megapixel  39.62 cm (15.6 Inch)
# ..                                                 ...                   ...
# 691                               HD type (30fps@720p)  39.62 cm (15.6 Inch)
# 692  FHD camera with IR function to support Windows...    35.56 cm (14 Inch)
# 693  1080p FHD camera with IR function to support W...    35.56 cm (14 Inch)
# 694  FHD camera with IR function to support Windows...    35.56 cm (14 inch)
# 695                                     720p HD camera  39.62 cm (15.6 inch)
#
#         Brand                            Processor    RAM    DDR  \
# 0      Lenovo  Intel Core i 5 Processor (13th Gen)  16 GB    DDR
# 1    MOTOROLA                            Not found  16 GB    DDR
# 2        Acer                            Not found   8 GB    DDR
# 3        ASUS  Intel Core i 3 Processor (13th Gen)   8 GB    DDR
# 4     SAMSUNG  Intel Core i 5 Processor (13th Gen)  16 GB  LPDDR
# ..        ...                                  ...    ...    ...
# 691       MSI  Intel Core i 5 Processor (12th Gen)  16 GB    DDR
# 692      ASUS                            Not found  32 GB  LPDDR
# 693      ASUS                            Not found  16 GB  LPDDR
# 694      ASUS  Intel Core i 7 Processor (13th Gen)  16 GB    DDR
# 695    Lenovo  Intel Core i 3 Processor (12th Gen)  16 GB    DDR
#
#                   OS     Storage               Display  \
# 0    Windows 11 Home    1 TB SSD    35.56 cm (14 inch)
# 1         Windows 11  512 GB SSD    35.56 cm (14 Inch)
# 2    Windows 11 Home  256 GB SSD  29.46 cm (11.6 inch)
# 3         Windows 11  512 GB SSD  39.62 cm (15.6 Inch)
# 4         Windows 11  512 GB SSD  39.62 cm (15.6 Inch)
# ..               ...         ...                   ...
# 691       Windows 11  512 GB SSD  39.62 cm (15.6 Inch)
# 692  Windows 11 Home    1 TB SSD    35.56 cm (14 Inch)
# 693  Windows 11 Home    1 TB SSD    35.56 cm (14 Inch)
# 694  Windows 11 Home  512 GB SSD    35.56 cm (14 inch)
# 695       Windows 11  512 GB SSD  39.62 cm (15.6 inch)
#
#                          Warranty  \
# 0    20241 Year Carry-in Warranty
# 1      20241 Year Onsite Warranty
# 2                 1 Year Warranty
# 3          1 Year Onsite Warranty
# 4                       Not found
# ..                            ...
# 691        2 Year Onsite Warranty
# 692                     Not found
# 693        1 Year Onsite Warranty
# 694        1 Year Onsite Warranty
# 695                     Not found
#
#                                                   text
# 0    Product: Lenovo IdeaPad Slim 5, Brand: Lenovo,...
# 1    Product: MOTOROLA Motobook 60 Full Metal, Bran...
# 2    Product: Acer Aspire 3, Brand: Acer, Rating: 3...
# 3    Product: ASUS Vivobook 15, Brand: ASUS, Rating...
# 4    Product: SAMSUNG Galaxy Book4 Metal, Brand: SA...
# ..                                                 ...
# 691  Product: MSI Thin 15, Brand: MSI, Rating: 4.3,...
# 692  Product: ASUS Zenbook 14 OLED, Brand: ASUS, Ra...
# 693  Product: ASUS Expertbook P5 full metal AI PC, ...
# 694  Product: ASUS Vivobook S14, Brand: ASUS, Ratin...
# 695  Product: Lenovo V 15, Brand: Lenovo, Rating: N...
#
# [696 rows x 18 columns]

# %%
df['text'][0]
# Out:
# 'Product: Lenovo IdeaPad Slim 5, Brand: Lenovo, Rating: Not found, Price: ₹97290, Processor: Intel Core i 5 Processor (13th Gen), RAM: 16 GB GB, DDR: DDR, OS: Windows 11 Home, Storage: 1 TB SSD, Weight: 1.39 Kg kg, Warranty: 20241 Year Carry-in Warranty'

# %%
df.columns
# Out:
# Index(['Product Name', 'Specifications', 'Rating', 'Price', 'Product URL',
#        'Battery Life', 'Weight', 'Webcam', 'Display Size', 'Brand',
#        'Processor', 'RAM', 'DDR', 'OS', 'Storage', 'Display', 'Warranty',
#        'text', 'all_text'],
#       dtype='object')

# %%
df["all_text"] = df.apply(lambda row: row.to_dict(), axis=1)

# %%
df.to_csv("flipkart_laptop_cleaned.csv", index=False)
print("✅ Cleaned data saved to flipkart_laptop_cleaned.csv")
# Out:
# ✅ Cleaned data saved to flipkart_laptop_cleaned.csv
